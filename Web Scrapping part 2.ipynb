# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd

# %%
url = 'https://www.fbi.gov/wanted/topten'

# %%
response = requests.get(url)
response.status_code
# Out:
# 403

# %%
url = 'https://data.gov.uk/'

# %%
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.content, "html.parser")

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]-->
# <!--[if gt IE 8]><!--><html lang="en"><!--<![endif]-->
# <html class="govuk-template">
# <head>
# <meta charset="utf-8"/>
# <title>Find open data - data.gov.uk</title>
# <meta content="#0b0c0c" name="theme-color">
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <link href="/find-assets/application-8b7545934ebe6ea0b37d1329e4ab1781289bbe3194049d0fcf13e5b605f3d694.css" media="screen" rel="stylesheet"/>
# <meta content="authenticity_token" name="csrf-param">
# <meta content="qx9zsf56l4GnhUIZMBtvXC2ThUEF9xWh1taUSJUDvTS9onRjOfy2ee-BDMlyP8AMu1P4RKaTYb1iCEVaJX1qyQ" name="csrf-token"/>
# </meta></meta></head>
# <body class="govuk-template__body">
# <script>document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');</script>
# ...

# %%
soup.select("#main-content > div:nth-child(3) > h2")
# Out:
# [<h2 class="govuk-visually-hidden">Data topics</h2>]

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 9]><html class="lte-ie8" lang="en"><![endif]-->
# <!--[if gt IE 8]><!-->
# <html lang="en">
#  <!--<![endif]-->
#  <html class="govuk-template">
#   <head>
#    <meta charset="utf-8"/>
#    <title>
#     Find open data - data.gov.uk
#    </title>
#    <meta content="#0b0c0c" name="theme-color">
#     <meta content="width=device-width, initial-scale=1" name="viewport"/>
#     <link href="/find-assets/application-8b7545934ebe6ea0b37d1329e4ab1781289bbe3194049d0fcf13e5b605f3d694.css" media="screen" rel="stylesheet"/>
#     <meta content="authenticity_token" name="csrf-param">
#      <meta content="qx9zsf56l4GnhUIZMBtvXC2ThUEF9xWh1taUSJUDvTS9onRjOfy2ee-BDMlyP8AMu1P4RKaTYb1iCEVaJX1qyQ" name="csrf-token"/>
#     </meta>
#    </meta>
#   </head>
#   <body class="govuk-template__body">
#    <script>
#     document.body.className = ((document.body.className) ? document.body.className + ' js-enabled' : 'js-enabled');
#    </script>
# ...

# %%
soup.select("#main-content > div:nth-child(3)")
# Out:
# []

# %%
prestab = soup.select("li")[3]
prestab.select("li h3 a ")
# Out:
# [<a class="govuk-link" href="/search?filters%5Btopic%5D=Business+and+economy">Business and economy</a>]

# %%
list = soup.select("#main-content > div:nth-child(3)")

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# URL of the target website
url = "https://www.data.gov.uk/"

# Sending an HTTP GET request to the URL
response = requests.get(url)

# Checking if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Finding all the dataset titles using the specified CSS selector
    dataset_types = soup.find_all('h3', class_='govuk-heading-s dgu-topics__heading')
    
    # Extracting the text from the titles and store them in a list
    #data_set_titles = [dataset.get_text() for dataset in dataset_types]
    
    # Creating a DataFrame from the list of titles
    #data_sets = pd.DataFrame({'Data Set Titles': data_set_titles})
    
    # Printing the first few rows of the DataFrame
    #print(data_sets.head())
    
    # You can also save the DataFrame to a CSV file if needed
    #data_sets.to_csv('data_sets.csv', index=False)

#else:
    #print("Failed to retrieve the webpage. Status code:", response.status_code)

# %%
data_set_titles
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %%
dataset_types = soup.find_all('h3', class_='govuk-heading-s dgu-topics__heading')
types_list = [dataset.get_text() for dataset in dataset_types]
types_list
# Out:
# ['Business and economy',
#  'Crime and justice',
#  'Defence',
#  'Education',
#  'Environment',
#  'Government',
#  'Government spending',
#  'Health',
#  'Mapping',
#  'Society',
#  'Towns and cities',
#  'Transport',
#  'Digital service performance',
#  'Government reference data']

# %%
url = "https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Selecting the specific table row elements
table_rows = soup.select('#mw-content-text table.wikitable tbody tr')

# %%
url = "https://en.wikipedia.org/wiki/List_of_languages_by_number_of_native_speakers"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

table_rows = soup.select('#mw-content-text table.wikitable tbody tr')
data = []
for row in table_rows[:11]:  # Select only the first 10 rows
    language_name = row.select_one('td:nth-child(1) a')
    speakers = row.select_one('td:nth-child(2)')
    language_family = row.select_one('td:nth-child(3) a')
    branch = row.select_one('td:nth-child(4) a')
    if language_name and speakers and speakers.text.strip().replace('.', '').isdigit() and language_family and branch:
        data.append({
            "Language": language_name.text.strip(),
            "Speakers": float(speakers.text.strip().replace(',', '')),
            "Language Family": language_family.text.strip(),
            "Branch": branch.text.strip()
        })

df = pd.DataFrame(data)
df
# Out:
#            Language  Speakers Language Family        Branch
# 0  Mandarin Chinese     939.0    Sino-Tibetan       Sinitic
# 1           Spanish     485.0   Indo-European       Romance
# 2           English     380.0   Indo-European      Germanic
# 3             Hindi     345.0   Indo-European    Indo-Aryan
# 4        Portuguese     236.0   Indo-European       Romance
# 5           Bengali     234.0   Indo-European    Indo-Aryan
# 6           Russian     147.0   Indo-European  Balto-Slavic
# 7          Japanese     123.0         Japonic      Japanese
# 8       Yue Chinese      86.1    Sino-Tibetan       Sinitic
# 9        Vietnamese      85.0   Austroasiatic        Vietic

# %%
import requests
from bs4 import BeautifulSoup

# URL of the target Wikipedia page
url = "https://en.wikipedia.org/wiki/Python"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the table with the specified summary table's caption
    summary_table = soup.select_one('#mw-content-text > div.mw-content-ltr.mw-parser-output > table.wikitable > tbody')
    
    if summary_table:
        # Find all the links within the table
        links = summary_table.find_all('a', href=True, title=True)
        
        # Extract the href and title attributes of the links
        link_data = [{'title': link['title'], 'href': link['href']} for link in links]
        
        # Print the list of links and titles
        for item in link_data:
            print("Title:", item['title'])
            print("Href:", item['href'])
            print()
    else:
        print("Summary table not found on the page.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Summary table not found on the page.

# %%
import requests
from bs4 import BeautifulSoup

# URL of the target Wikipedia page
url = "https://en.wikipedia.org/wiki/Python"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find the table with the specified summary table's caption
    summary_table = soup.select_one('#mw-content-text > div.mw-content-ltr.mw-parser-output > table.wikitable')
    
    if summary_table:
        # Find all the links within the table
        links = summary_table.find_all('a', href=True, title=True)
        
        # Extract the href and title attributes of the links
        link_data = [{'title': link['title'], 'href': link['href']} for link in links]
        
        # Print the list of links and titles
        for item in link_data:
            print("Title:", item['title'])
            print("Href:", item['href'])
            print()
    else:
        print("Summary table not found on the page.")
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Summary table not found on the page.

# %%
import requests
from bs4 import BeautifulSoup

# URL of the target Wikipedia page
url = "https://en.wikipedia.org/wiki/Python_(programming_language)"

# Send an HTTP GET request to the URL
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    # Parse the HTML content of the page using BeautifulSoup
    soup = BeautifulSoup(response.text, 'html.parser')
    
    # Find all the links on the page
    links = soup.find_all('a', href=True)
    
    # Extract the href attributes of the links
    link_data = [link['href'] for link in links]
    
    # Print the list of links
    for item in link_data:
        print("Link:", item)
else:
    print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# Link: #bodyContent
# Link: /wiki/Main_Page
# Link: /wiki/Wikipedia:Contents
# Link: /wiki/Portal:Current_events
# Link: /wiki/Special:Random
# Link: /wiki/Wikipedia:About
# Link: //en.wikipedia.org/wiki/Wikipedia:Contact_us
# Link: https://donate.wikimedia.org/wiki/Special:FundraiserRedirector?utm_source=donate&utm_medium=sidebar&utm_campaign=C13_en.wikipedia.org&uselang=en
# Link: /wiki/Help:Contents
# Link: /wiki/Help:Introduction
# Link: /wiki/Wikipedia:Community_portal
# Link: /wiki/Special:RecentChanges
# Link: /wiki/Wikipedia:File_upload_wizard
# Link: /wiki/Main_Page
# Link: /wiki/Special:Search
# Link: /w/index.php?title=Special:CreateAccount&returnto=Python+%28programming+language%29
# Link: /w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29
# Link: /w/index.php?title=Special:CreateAccount&returnto=Python+%28programming+language%29
# Link: /w/index.php?title=Special:UserLogin&returnto=Python+%28programming+language%29
# ...
